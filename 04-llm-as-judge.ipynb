# %%
import pandas as pd

df_answers = pd.read_csv("data/rag-answers-new.csv")
answers = df_answers.to_dict(orient="records")

# %%
from pydantic import BaseModel, Field
from typing import Literal

class AnswerEvaluation(BaseModel):
    reasoning: str = Field(
        description="Reasoning about the quality of the answer."
    )
    score: Literal["good", "bad"] = Field(
        description="'good' if the answer is correct and complete, 'bad' otherwise."
    )

# %%
aqa_judge_instructions = """
You are an expert evaluator. You will be given:
1. A question from a student
2. The original answer from the FAQ (ground truth)
3. An answer generated by an AI assistant

Your task is to decide if the AI answer is semantically equivalent to
the original answer.

Rules:
- The AI answer does NOT need to be word-for-word identical
- It should convey the same key information
- Extra detail is fine as long as the core answer is correct
- Mark 'bad' only if the AI answer is wrong or misses the key point

Be fair and focus on correctness, not style.
""".strip()

# %%
from dotenv import load_dotenv
from openai import OpenAI
from evaluation_utils import calc_price, calc_total_price, llm_structured_retry, map_progress

from openai import OpenAI
import os

openai_client = OpenAI(
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1"
)

# %%
rec = answers[0]

# %%
aqa_judge_prompt = """
Question:
{question}

Original Answer (ground truth):
{answer_orig}

AI Answer:
{answer_llm}
""".strip()

# %%
judge prompt

# %%
prompt = aqa_judge_prompt.format(
    question=rec["question"],
    answer_orig=rec["answer_orig"],
    answer_llm=rec["answer_llm"]
)

# %%
eval_result, usage = llm_structured_retry(
    openai_client,
    aqa_judge_instructions,
    prompt,
    AnswerEvaluation,
)

eval_result
# Out:
# ---------------------------------------------------------------------------
# APIStatusError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 eval_result, usage = llm_structured_retry(
#       2     openai_client,
#       3     aqa_judge_instructions,
#       4     prompt,
#
# File /workspaces/llm-zoomcamp-evaluation/evaluation_utils.py:62, in llm_structured_retry(client, instructions, user_prompt, output_type, model, max_retries)
#      60 for attempt in range(max_retries):
#      61     try:
# ---> 62         return llm_structured(
#      63             client,
#      64             instructions,
#      65             user_prompt,
#      66             output_type,
#      67             model=model,
#      68         )
#      69     except Exception:
#      70         if attempt == max_retries - 1:
#
# File /workspaces/llm-zoomcamp-evaluation/evaluation_utils.py:38, in llm_structured(client, instructions, user_prompt, output_type, model)
#      32 def llm_structured(client, instructions, user_prompt, output_type, model="openai/gpt-5.4-mini"):
#      33     messages = [
#      34         {"role": "developer", "content": instructions},
#      35         {"role": "user", "content": user_prompt}
#      36     ]
# ---> 38     response = client.responses.parse(
#      39         model=model,
#      40         input=messages,
#      41         text_format=output_type,
#      42         max_output_tokens=2000
#      43     )
#      45     return response.output_parsed, response.usage
#
# File /workspaces/llm-zoomcamp-evaluation/.venv/lib/python3.12/site-packages/openai/resources/responses/responses.py:1338, in Responses.parse(self, text_format, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, moderation, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, verbosity, extra_headers, extra_query, extra_body, timeout)
#    1331 def parser(raw_response: Response) -> ParsedResponse[TextFormatT]:
#    1332     return parse_response(
#    1333         input_tools=tools,
#    1334         text_format=text_format,
#    1335         response=raw_response,
#    1336     )
# -> 1338 return self._post(
#    1339     "/responses",
#    1340     body=maybe_transform(
#    1341         {
#    1342             "background": background,
#    1343             "context_management": context_management,
#    1344             "conversation": conversation,
#    1345             "include": include,
#    1346             "input": input,
#    1347             "instructions": instructions,
#    1348             "max_output_tokens": max_output_tokens,
#    1349             "max_tool_calls": max_tool_calls,
#    1350             "metadata": metadata,
#    1351             "model": model,
#    1352             "moderation": moderation,
#    1353             "parallel_tool_calls": parallel_tool_calls,
#    1354             "previous_response_id": previous_response_id,
#    1355             "prompt": prompt,
#    1356             "prompt_cache_key": prompt_cache_key,
#    1357             "prompt_cache_options": prompt_cache_options,
#    1358             "prompt_cache_retention": prompt_cache_retention,
#    1359             "reasoning": reasoning,
#    1360             "safety_identifier": safety_identifier,
#    1361             "service_tier": service_tier,
#    1362             "store": store,
#    1363             "stream": stream,
#    1364             "stream_options": stream_options,
#    1365             "temperature": temperature,
#    1366             "text": text,
#    1367             "tool_choice": tool_choice,
#    1368             "tools": tools,
#    1369             "top_logprobs": top_logprobs,
#    1370             "top_p": top_p,
#    1371             "truncation": truncation,
#    1372             "user": user,
#    1373             "verbosity": verbosity,
#    1374         },
#    1375         response_create_params.ResponseCreateParams,
#    1376     ),
#    1377     options=make_request_options(
#    1378         extra_headers=extra_headers,
#    1379         extra_query=extra_query,
#    1380         extra_body=extra_body,
#    1381         timeout=timeout,
#    1382         post_parser=parser,
#    1383         security={"bearer_auth": True},
#    1384     ),
#    1385     # we turn the `Response` instance into a `ParsedResponse`
#    1386     # in the `parser` function above
#    1387     cast_to=cast(Type[ParsedResponse[TextFormatT]], Response),
#    1388 )
#
# File /workspaces/llm-zoomcamp-evaluation/.venv/lib/python3.12/site-packages/openai/_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /workspaces/llm-zoomcamp-evaluation/.venv/lib/python3.12/site-packages/openai/_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# APIStatusError: Error code: 402 - {'error': {'message': 'Insufficient credits. This account never purchased credits. Make sure your key is on the correct account or org, and if so, purchase more at https://openrouter.ai/settings/credits', 'code': 402}}

# %%
def evaluate_aqa(question, answer_orig, answer_llm, model="gpt-5.4-mini"):
    prompt = aqa_judge_prompt.format(
        question=question,
        answer_orig=answer_orig,
        answer_llm=answer_llm
    )

    result, usage = llm_structured_retry(
        openai_client,
        aqa_judge_instructions,
        prompt,
        AnswerEvaluation,
        model=model,
    )

    return result, usage

# %%
eval_result, usage = evaluate_aqa(
    question=rec["question"],
    answer_orig=rec["answer_orig"],
    answer_llm=rec["answer_llm"]
)

eval_result

# %%
def judge_record(rec):
    eval_result, usage = evaluate_aqa(
        question=rec["question"],
        answer_orig=rec["answer_orig"],
        answer_llm=rec["answer_llm"]
    )

    result = {
        "question": rec["question"],
        "document": rec["document"],
        "score": eval_result.score,
        "reasoning": eval_result.reasoning,
    }

    return result, usage

# %%
from concurrent.futures import ThreadPoolExecutor

with ThreadPoolExecutor(max_workers=6) as pool:
    results = map_progress(pool, answers, judge_record)

# %%
evaluations = []
usages = []

for evaluation, usage in results:
    evaluations.append(evaluation)
    usages.append(usage)

# %%
df_eval = pd.DataFrame(evaluations)

# %%
good_count = (df_eval["score"] == "good").sum()
total_count = len(df_eval)
print(f"Good: {good_count}/{total_count} = {good_count/total_count:.2%}")

# %%
df_eval[df_eval["score"] == "bad"].head()

# %%
df_eval.to_csv("data/rag-evaluations-new.csv", index=False)
